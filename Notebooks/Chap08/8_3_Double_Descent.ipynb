# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('int64'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('int64'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304276, train error 90.20,  test loss 2.303516, test error 89.82
# Epoch   100, train loss 1.879335, train error 70.15,  test loss 1.723400, test error 69.50
# Epoch   200, train loss 1.861368, train error 69.85,  test loss 1.700699, test error 68.75
# Epoch   300, train loss 1.856007, train error 69.68,  test loss 1.701554, test error 68.47
# Epoch   400, train loss 1.853900, train error 69.53,  test loss 1.706791, test error 68.00
# Epoch   500, train loss 1.850646, train error 69.57,  test loss 1.704464, test error 68.38
# Epoch   600, train loss 1.850565, train error 69.10,  test loss 1.703356, test error 68.15
# Epoch   700, train loss 1.849996, train error 69.93,  test loss 1.707026, test error 67.57
# Epoch   800, train loss 1.848178, train error 69.78,  test loss 1.703169, test error 67.43
# Epoch   900, train loss 1.848247, train error 69.88,  test loss 1.708076, test error 68.07
# Training model with   4 hidden variables
# Epoch     0, train loss 2.271354, train error 83.25,  test loss 2.273255, test error 83.97
# Epoch   100, train loss 1.737456, train error 64.55,  test loss 1.570200, test error 63.20
# Epoch   200, train loss 1.688030, train error 61.53,  test loss 1.508807, test error 57.95
# Epoch   300, train loss 1.678321, train error 61.33,  test loss 1.506046, test error 57.65
# Epoch   400, train loss 1.680806, train error 61.10,  test loss 1.517677, test error 58.33
# Epoch   500, train loss 1.681920, train error 60.88,  test loss 1.516920, test error 58.10
# Epoch   600, train loss 1.691127, train error 61.78,  test loss 1.522792, test error 57.83
# Epoch   700, train loss 1.675098, train error 60.78,  test loss 1.505134, test error 57.88
# Epoch   800, train loss 1.685328, train error 60.42,  test loss 1.513171, test error 58.12
# Epoch   900, train loss 1.673923, train error 60.62,  test loss 1.505257, test error 57.72
# Training model with   6 hidden variables
# Epoch     0, train loss 2.265550, train error 85.88,  test loss 2.261218, test error 85.72
# Epoch   100, train loss 1.730283, train error 64.75,  test loss 1.583498, test error 63.28
# Epoch   200, train loss 1.685907, train error 61.72,  test loss 1.550910, test error 60.45
# Epoch   300, train loss 1.671074, train error 61.67,  test loss 1.548673, test error 60.83
# Epoch   400, train loss 1.661182, train error 61.78,  test loss 1.555855, test error 61.30
# Epoch   500, train loss 1.660774, train error 61.75,  test loss 1.563226, test error 61.05
# Epoch   600, train loss 1.657111, train error 60.92,  test loss 1.564179, test error 61.12
# Epoch   700, train loss 1.651384, train error 60.80,  test loss 1.573776, test error 61.45
# Epoch   800, train loss 1.654288, train error 61.10,  test loss 1.585586, test error 61.55
# Epoch   900, train loss 1.653092, train error 61.38,  test loss 1.575101, test error 61.10
# Training model with   8 hidden variables
# Epoch     0, train loss 2.250226, train error 83.72,  test loss 2.238297, test error 83.85
# Epoch   100, train loss 1.579852, train error 55.40,  test loss 1.428642, test error 54.10
# Epoch   200, train loss 1.488653, train error 50.72,  test loss 1.297876, test error 48.00
# Epoch   300, train loss 1.462299, train error 49.88,  test loss 1.276772, test error 47.22
# Epoch   400, train loss 1.447522, train error 48.72,  test loss 1.281398, test error 47.50
# Epoch   500, train loss 1.441158, train error 48.90,  test loss 1.279158, test error 46.97
# Epoch   600, train loss 1.436593, train error 48.75,  test loss 1.284948, test error 47.30
# Epoch   700, train loss 1.436966, train error 49.03,  test loss 1.297477, test error 47.92
# Epoch   800, train loss 1.433095, train error 48.72,  test loss 1.292816, test error 47.60
# Epoch   900, train loss 1.431948, train error 48.88,  test loss 1.305916, test error 47.55
# Training model with  10 hidden variables
# Epoch     0, train loss 2.253274, train error 84.85,  test loss 2.256622, test error 85.57
# Epoch   100, train loss 1.593736, train error 56.58,  test loss 1.479079, test error 55.67
# Epoch   200, train loss 1.497857, train error 51.50,  test loss 1.374463, test error 52.20
# Epoch   300, train loss 1.467642, train error 50.67,  test loss 1.360538, test error 51.55
# Epoch   400, train loss 1.452599, train error 50.30,  test loss 1.366387, test error 50.83
# Epoch   500, train loss 1.445108, train error 49.85,  test loss 1.365302, test error 50.78
# Epoch   600, train loss 1.436607, train error 48.97,  test loss 1.359684, test error 50.78
# Epoch   700, train loss 1.429977, train error 48.62,  test loss 1.358822, test error 51.17
# Epoch   800, train loss 1.424384, train error 49.15,  test loss 1.361867, test error 51.88
# Epoch   900, train loss 1.420623, train error 48.60,  test loss 1.355299, test error 50.92
# Training model with  14 hidden variables
# Epoch     0, train loss 2.277882, train error 85.07,  test loss 2.280505, test error 85.12
# Epoch   100, train loss 1.437383, train error 48.90,  test loss 1.369185, test error 51.33
# Epoch   200, train loss 1.378767, train error 46.80,  test loss 1.403973, test error 53.53
# Epoch   300, train loss 1.361201, train error 46.12,  test loss 1.431151, test error 53.28
# Epoch   400, train loss 1.352548, train error 45.72,  test loss 1.446074, test error 54.35
# Epoch   500, train loss 1.332856, train error 45.20,  test loss 1.436836, test error 53.12
# Epoch   600, train loss 1.322404, train error 44.83,  test loss 1.441557, test error 52.45
# Epoch   700, train loss 1.317985, train error 44.83,  test loss 1.463403, test error 53.70
# Epoch   800, train loss 1.325774, train error 44.72,  test loss 1.465041, test error 53.10
# Epoch   900, train loss 1.320538, train error 45.20,  test loss 1.488302, test error 52.90
# Training model with  18 hidden variables
# Epoch     0, train loss 2.229010, train error 82.70,  test loss 2.202381, test error 81.65
# Epoch   100, train loss 1.330604, train error 44.33,  test loss 1.289006, test error 47.30
# Epoch   200, train loss 1.236765, train error 41.72,  test loss 1.302854, test error 47.45
# Epoch   300, train loss 1.196565, train error 40.62,  test loss 1.341720, test error 49.08
# Epoch   400, train loss 1.174210, train error 40.03,  test loss 1.389360, test error 50.30
# Epoch   500, train loss 1.162536, train error 39.58,  test loss 1.454609, test error 50.30
# Epoch   600, train loss 1.136006, train error 38.12,  test loss 1.442722, test error 49.47
# Epoch   700, train loss 1.131394, train error 38.62,  test loss 1.467168, test error 50.22
# Epoch   800, train loss 1.118905, train error 37.65,  test loss 1.483295, test error 50.67
# Epoch   900, train loss 1.113796, train error 37.42,  test loss 1.525123, test error 50.60
# Training model with  22 hidden variables
# Epoch     0, train loss 2.104158, train error 78.60,  test loss 2.052031, test error 76.93
# Epoch   100, train loss 1.251795, train error 43.40,  test loss 1.285864, test error 49.00
# Epoch   200, train loss 1.127646, train error 38.60,  test loss 1.358474, test error 49.03
# Epoch   300, train loss 1.064681, train error 36.42,  test loss 1.440337, test error 50.97
# Epoch   400, train loss 1.027118, train error 34.95,  test loss 1.515552, test error 51.85
# Epoch   500, train loss 1.000011, train error 34.65,  test loss 1.567763, test error 52.00
# Epoch   600, train loss 0.982658, train error 34.20,  test loss 1.628106, test error 52.72
# Epoch   700, train loss 0.959692, train error 32.60,  test loss 1.660897, test error 53.28
# Epoch   800, train loss 0.948533, train error 32.57,  test loss 1.713475, test error 53.15
# Epoch   900, train loss 0.942048, train error 31.95,  test loss 1.729617, test error 53.05
# Training model with  26 hidden variables
# Epoch     0, train loss 2.170002, train error 78.43,  test loss 2.130125, test error 78.97
# Epoch   100, train loss 1.236330, train error 40.60,  test loss 1.318835, test error 48.50
# Epoch   200, train loss 1.078715, train error 35.57,  test loss 1.373898, test error 48.85
# Epoch   300, train loss 1.010014, train error 33.50,  test loss 1.490495, test error 49.70
# Epoch   400, train loss 0.980188, train error 33.28,  test loss 1.605807, test error 50.88
# Epoch   500, train loss 0.944793, train error 31.80,  test loss 1.687894, test error 51.12
# Epoch   600, train loss 0.908872, train error 30.97,  test loss 1.802269, test error 51.03
# Epoch   700, train loss 0.885527, train error 29.53,  test loss 1.849426, test error 51.30
# Epoch   800, train loss 0.878171, train error 29.88,  test loss 1.977175, test error 51.78
# Epoch   900, train loss 0.858995, train error 29.43,  test loss 2.003135, test error 51.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.184549, train error 81.35,  test loss 2.143451, test error 80.45
# Epoch   100, train loss 1.128841, train error 37.08,  test loss 1.378584, test error 50.50
# Epoch   200, train loss 0.940804, train error 31.72,  test loss 1.615301, test error 51.72
# Epoch   300, train loss 0.846562, train error 28.53,  test loss 1.828923, test error 52.53
# Epoch   400, train loss 0.780486, train error 26.68,  test loss 2.043653, test error 53.88
# Epoch   500, train loss 0.740781, train error 24.90,  test loss 2.226807, test error 54.80
# Epoch   600, train loss 0.721665, train error 24.55,  test loss 2.385714, test error 53.92
# Epoch   700, train loss 0.695021, train error 24.25,  test loss 2.567616, test error 55.12
# Epoch   800, train loss 0.684468, train error 23.57,  test loss 2.701232, test error 55.38
# Epoch   900, train loss 0.641255, train error 21.45,  test loss 2.859893, test error 55.62
# Training model with  35 hidden variables
# Epoch     0, train loss 2.199610, train error 80.05,  test loss 2.178377, test error 80.97
# Epoch   100, train loss 1.031320, train error 33.57,  test loss 1.387589, test error 51.08
# Epoch   200, train loss 0.797602, train error 27.50,  test loss 1.698593, test error 53.03
# Epoch   300, train loss 0.671108, train error 22.75,  test loss 2.001600, test error 53.62
# Epoch   400, train loss 0.611390, train error 20.95,  test loss 2.385253, test error 54.70
# Epoch   500, train loss 0.565876, train error 19.45,  test loss 2.704959, test error 55.67
# Epoch   600, train loss 0.533548, train error 18.47,  test loss 2.995589, test error 55.35
# Epoch   700, train loss 0.517126, train error 17.88,  test loss 3.252820, test error 56.00
# Epoch   800, train loss 0.511180, train error 18.12,  test loss 3.540539, test error 56.30
# Epoch   900, train loss 0.474161, train error 17.32,  test loss 3.826229, test error 56.42
# Training model with  40 hidden variables
# Epoch     0, train loss 2.085181, train error 78.53,  test loss 2.050369, test error 78.88
# Epoch   100, train loss 0.958896, train error 31.45,  test loss 1.398477, test error 49.30
# Epoch   200, train loss 0.671552, train error 22.18,  test loss 1.810410, test error 52.83
# Epoch   300, train loss 0.506784, train error 17.03,  test loss 2.432038, test error 54.97
# Epoch   400, train loss 0.424421, train error 13.55,  test loss 3.112258, test error 56.05
# Epoch   500, train loss 0.352149, train error 11.95,  test loss 3.853039, test error 56.92
# Epoch   600, train loss 0.342163, train error 11.50,  test loss 4.443101, test error 56.22
# Epoch   700, train loss 0.261481, train error 8.15,  test loss 5.145876, test error 57.70
# Epoch   800, train loss 0.224906, train error 6.95,  test loss 5.790099, test error 57.45
# Epoch   900, train loss 0.228775, train error 7.82,  test loss 6.397782, test error 57.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.085627, train error 76.32,  test loss 2.051837, test error 76.57
# Epoch   100, train loss 0.845436, train error 27.03,  test loss 1.550559, test error 51.12
# Epoch   200, train loss 0.518155, train error 16.35,  test loss 2.292142, test error 54.12
# Epoch   300, train loss 0.306596, train error 8.68,  test loss 3.350182, test error 55.47
# Epoch   400, train loss 0.227119, train error 7.20,  test loss 4.607882, test error 56.50
# Epoch   500, train loss 0.166136, train error 5.70,  test loss 6.004777, test error 57.28
# Epoch   600, train loss 0.213947, train error 7.45,  test loss 7.402585, test error 58.50
# Epoch   700, train loss 0.136456, train error 4.80,  test loss 8.540272, test error 58.62
# Epoch   800, train loss 0.008989, train error 0.00,  test loss 9.400075, test error 58.62
# Epoch   900, train loss 0.005599, train error 0.00,  test loss 10.030472, test error 58.80
# Training model with  50 hidden variables
# Epoch     0, train loss 2.076053, train error 76.70,  test loss 2.014854, test error 75.28
# Epoch   100, train loss 0.725559, train error 23.97,  test loss 1.605097, test error 50.83
# Epoch   200, train loss 0.320753, train error 9.28,  test loss 2.710925, test error 53.88
# Epoch   300, train loss 0.120159, train error 2.47,  test loss 4.380791, test error 55.80
# Epoch   400, train loss 0.024678, train error 0.00,  test loss 5.848979, test error 55.85
# Epoch   500, train loss 0.012217, train error 0.00,  test loss 6.733602, test error 56.20
# Epoch   600, train loss 0.007884, train error 0.00,  test loss 7.327504, test error 56.35
# Epoch   700, train loss 0.005684, train error 0.00,  test loss 7.760432, test error 56.40
# Epoch   800, train loss 0.004391, train error 0.00,  test loss 8.125482, test error 56.62
# Epoch   900, train loss 0.003536, train error 0.00,  test loss 8.425787, test error 56.53
# Training model with  55 hidden variables
# Epoch     0, train loss 2.115030, train error 78.35,  test loss 2.098381, test error 77.97
# Epoch   100, train loss 0.585576, train error 16.93,  test loss 1.633300, test error 50.38
# Epoch   200, train loss 0.203942, train error 4.95,  test loss 3.010574, test error 53.62
# Epoch   300, train loss 0.039417, train error 0.03,  test loss 4.621408, test error 55.40
# Epoch   400, train loss 0.014358, train error 0.00,  test loss 5.567002, test error 55.62
# Epoch   500, train loss 0.008510, train error 0.00,  test loss 6.170764, test error 55.83
# Epoch   600, train loss 0.005807, train error 0.00,  test loss 6.597364, test error 56.03
# Epoch   700, train loss 0.004398, train error 0.00,  test loss 6.932565, test error 56.10
# Epoch   800, train loss 0.003466, train error 0.00,  test loss 7.203754, test error 56.12
# Epoch   900, train loss 0.002847, train error 0.00,  test loss 7.439694, test error 56.20
# Training model with  60 hidden variables
# Epoch     0, train loss 2.038719, train error 75.12,  test loss 1.974075, test error 75.80
# Epoch   100, train loss 0.532813, train error 15.00,  test loss 1.702651, test error 49.65
# Epoch   200, train loss 0.124940, train error 2.15,  test loss 3.322789, test error 52.28
# Epoch   300, train loss 0.020677, train error 0.00,  test loss 4.634667, test error 53.10
# Epoch   400, train loss 0.009772, train error 0.00,  test loss 5.330666, test error 53.28
# Epoch   500, train loss 0.006152, train error 0.00,  test loss 5.780299, test error 53.10
# Epoch   600, train loss 0.004346, train error 0.00,  test loss 6.118701, test error 53.55
# Epoch   700, train loss 0.003317, train error 0.00,  test loss 6.378946, test error 53.53
# Epoch   800, train loss 0.002663, train error 0.00,  test loss 6.597390, test error 53.58
# Epoch   900, train loss 0.002213, train error 0.00,  test loss 6.781547, test error 53.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.065960, train error 76.62,  test loss 2.007239, test error 76.22
# Epoch   100, train loss 0.372893, train error 8.97,  test loss 1.836381, test error 50.97
# Epoch   200, train loss 0.037106, train error 0.00,  test loss 3.445509, test error 52.50
# Epoch   300, train loss 0.011275, train error 0.00,  test loss 4.237787, test error 52.62
# Epoch   400, train loss 0.006160, train error 0.00,  test loss 4.667630, test error 52.75
# Epoch   500, train loss 0.004104, train error 0.00,  test loss 4.965357, test error 52.72
# Epoch   600, train loss 0.003031, train error 0.00,  test loss 5.190782, test error 52.75
# Epoch   700, train loss 0.002374, train error 0.00,  test loss 5.374824, test error 52.70
# Epoch   800, train loss 0.001939, train error 0.00,  test loss 5.527744, test error 52.62
# Epoch   900, train loss 0.001626, train error 0.00,  test loss 5.657806, test error 52.65
# Training model with  80 hidden variables
# Epoch     0, train loss 2.034170, train error 75.57,  test loss 1.997955, test error 76.43
# Epoch   100, train loss 0.235837, train error 4.12,  test loss 2.099233, test error 52.33
# Epoch   200, train loss 0.019917, train error 0.00,  test loss 3.481166, test error 53.22
# Epoch   300, train loss 0.007908, train error 0.00,  test loss 4.031783, test error 53.28
# Epoch   400, train loss 0.004661, train error 0.00,  test loss 4.364902, test error 53.35
# Epoch   500, train loss 0.003221, train error 0.00,  test loss 4.601426, test error 53.40
# Epoch   600, train loss 0.002425, train error 0.00,  test loss 4.781481, test error 53.40
# Epoch   700, train loss 0.001925, train error 0.00,  test loss 4.930704, test error 53.42
# Epoch   800, train loss 0.001586, train error 0.00,  test loss 5.053932, test error 53.53
# Epoch   900, train loss 0.001340, train error 0.00,  test loss 5.160454, test error 53.33
# Training model with  90 hidden variables
# Epoch     0, train loss 2.014993, train error 74.18,  test loss 1.963208, test error 74.38
# Epoch   100, train loss 0.150375, train error 1.20,  test loss 2.282246, test error 52.35
# Epoch   200, train loss 0.015101, train error 0.00,  test loss 3.345651, test error 52.15
# Epoch   300, train loss 0.006668, train error 0.00,  test loss 3.795900, test error 52.20
# Epoch   400, train loss 0.004060, train error 0.00,  test loss 4.064351, test error 52.15
# Epoch   500, train loss 0.002853, train error 0.00,  test loss 4.260905, test error 52.15
# Epoch   600, train loss 0.002167, train error 0.00,  test loss 4.413697, test error 52.25
# Epoch   700, train loss 0.001732, train error 0.00,  test loss 4.538183, test error 52.12
# Epoch   800, train loss 0.001434, train error 0.00,  test loss 4.643207, test error 52.03
# Epoch   900, train loss 0.001217, train error 0.00,  test loss 4.735092, test error 52.12
# Training model with 100 hidden variables
# Epoch     0, train loss 1.985442, train error 73.60,  test loss 1.930361, test error 74.35
# Epoch   100, train loss 0.093089, train error 0.12,  test loss 2.294420, test error 52.25
# Epoch   200, train loss 0.012427, train error 0.00,  test loss 3.174060, test error 52.00
# Epoch   300, train loss 0.005759, train error 0.00,  test loss 3.550894, test error 52.10
# Epoch   400, train loss 0.003596, train error 0.00,  test loss 3.786232, test error 52.25
# Epoch   500, train loss 0.002556, train error 0.00,  test loss 3.958330, test error 52.45
# Epoch   600, train loss 0.001956, train error 0.00,  test loss 4.091893, test error 52.38
# Epoch   700, train loss 0.001571, train error 0.00,  test loss 4.204209, test error 52.50
# Epoch   800, train loss 0.001306, train error 0.00,  test loss 4.298589, test error 52.38
# Epoch   900, train loss 0.001111, train error 0.00,  test loss 4.380255, test error 52.28
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975446, train error 73.43,  test loss 1.909843, test error 73.82
# Epoch   100, train loss 0.050087, train error 0.00,  test loss 2.199004, test error 49.25
# Epoch   200, train loss 0.009446, train error 0.00,  test loss 2.817362, test error 49.50
# Epoch   300, train loss 0.004677, train error 0.00,  test loss 3.102427, test error 49.67
# Epoch   400, train loss 0.002992, train error 0.00,  test loss 3.284703, test error 49.78
# Epoch   500, train loss 0.002158, train error 0.00,  test loss 3.418041, test error 49.70
# Epoch   600, train loss 0.001670, train error 0.00,  test loss 3.524333, test error 49.83
# Epoch   700, train loss 0.001350, train error 0.00,  test loss 3.611838, test error 49.92
# Epoch   800, train loss 0.001128, train error 0.00,  test loss 3.687323, test error 49.92
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.752134, test error 49.95
# Training model with 140 hidden variables
# Epoch     0, train loss 1.955772, train error 71.88,  test loss 1.881178, test error 73.38
# Epoch   100, train loss 0.037080, train error 0.00,  test loss 2.167283, test error 49.97
# Epoch   200, train loss 0.008134, train error 0.00,  test loss 2.672810, test error 49.85
# Epoch   300, train loss 0.004157, train error 0.00,  test loss 2.908118, test error 49.83
# Epoch   400, train loss 0.002697, train error 0.00,  test loss 3.062206, test error 49.88
# Epoch   500, train loss 0.001960, train error 0.00,  test loss 3.176080, test error 49.97
# Epoch   600, train loss 0.001523, train error 0.00,  test loss 3.267894, test error 50.05
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.343661, test error 50.15
# Epoch   800, train loss 0.001035, train error 0.00,  test loss 3.408696, test error 50.22
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.465275, test error 50.20
# Training model with 160 hidden variables
# Epoch     0, train loss 1.939357, train error 71.22,  test loss 1.841678, test error 71.88
# Epoch   100, train loss 0.030281, train error 0.00,  test loss 2.146652, test error 50.03
# Epoch   200, train loss 0.007457, train error 0.00,  test loss 2.563284, test error 49.67
# Epoch   300, train loss 0.003903, train error 0.00,  test loss 2.774709, test error 50.08
# Epoch   400, train loss 0.002559, train error 0.00,  test loss 2.913673, test error 50.25
# Epoch   500, train loss 0.001871, train error 0.00,  test loss 3.015402, test error 50.12
# Epoch   600, train loss 0.001459, train error 0.00,  test loss 3.098322, test error 50.30
# Epoch   700, train loss 0.001187, train error 0.00,  test loss 3.166779, test error 50.30
# Epoch   800, train loss 0.000996, train error 0.00,  test loss 3.225156, test error 50.25
# Epoch   900, train loss 0.000854, train error 0.00,  test loss 3.276092, test error 50.22
# Training model with 180 hidden variables
# Epoch     0, train loss 1.954584, train error 73.32,  test loss 1.841904, test error 71.22
# Epoch   100, train loss 0.024593, train error 0.00,  test loss 2.045058, test error 47.83
# Epoch   200, train loss 0.006688, train error 0.00,  test loss 2.396877, test error 47.83
# Epoch   300, train loss 0.003581, train error 0.00,  test loss 2.574664, test error 47.78
# Epoch   400, train loss 0.002368, train error 0.00,  test loss 2.692563, test error 47.80
# Epoch   500, train loss 0.001740, train error 0.00,  test loss 2.781327, test error 47.78
# Epoch   600, train loss 0.001363, train error 0.00,  test loss 2.851886, test error 47.88
# Epoch   700, train loss 0.001112, train error 0.00,  test loss 2.911548, test error 47.88
# Epoch   800, train loss 0.000935, train error 0.00,  test loss 2.962685, test error 47.88
# Epoch   900, train loss 0.000804, train error 0.00,  test loss 3.007108, test error 47.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.916639, train error 70.88,  test loss 1.835959, test error 73.12
# Epoch   100, train loss 0.021781, train error 0.00,  test loss 2.006087, test error 47.22
# Epoch   200, train loss 0.006176, train error 0.00,  test loss 2.324518, test error 47.28
# Epoch   300, train loss 0.003344, train error 0.00,  test loss 2.485642, test error 47.22
# Epoch   400, train loss 0.002227, train error 0.00,  test loss 2.596407, test error 47.15
# Epoch   500, train loss 0.001645, train error 0.00,  test loss 2.679463, test error 47.10
# Epoch   600, train loss 0.001291, train error 0.00,  test loss 2.745138, test error 47.03
# Epoch   700, train loss 0.001056, train error 0.00,  test loss 2.800513, test error 47.00
# Epoch   800, train loss 0.000889, train error 0.00,  test loss 2.848480, test error 47.12
# Epoch   900, train loss 0.000765, train error 0.00,  test loss 2.889887, test error 47.25
# Training model with 250 hidden variables
# Epoch     0, train loss 1.895009, train error 69.72,  test loss 1.794096, test error 70.05
# Epoch   100, train loss 0.017734, train error 0.00,  test loss 1.922841, test error 46.40
# Epoch   200, train loss 0.005459, train error 0.00,  test loss 2.169990, test error 45.72
# Epoch   300, train loss 0.003038, train error 0.00,  test loss 2.305645, test error 45.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 20
#      18 total_weights_all[c_hidden] = count_parameters(model)
#      19 # Train the model
# ---> 20 errors_train, errors_test = fit_model(model, data, n_epoch)
#      21 # Store the results
#      22 errors_train_all[c_hidden] = errors_train
#
# Cell In[19], line 35, in fit_model(model, data, n_epoch)
#      32   optimizer.step()
#      34 # Run whole dataset to get statistics -- normally wouldn't do this
# ---> 35 pred_train = model(x_train)
#      36 pred_test = model(x_test)
#      37 _, predicted_train_class = torch.max(pred_train.data, 1)
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\91824\Documents\Codes\deep-learning\udlbook\Notebooks\.venv\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
